# %% [markdown]
# ### Manipulación y transformación de datos I

# %%
import pandas as pd
import numpy as np

rubros = ['vestuario', 'calzado', 'hogar']
n_rubros = len(rubros)

#Creo dataframe de los rubros de venta

df = pd.DataFrame({
    'id':range(0,n_rubros), 
    'des_rubro':rubros
})
df
# Out:
#    id  des_rubro
# 0   0  vestuario
# 1   1    calzado
# 2   2      hogar

# %%
# Genero 100 ventas

n_ventas = 100

df_ventas = pd.DataFrame({
    'id':range(0,n_ventas),
    'rubro': np.random.randint(0,n_rubros,n_ventas),
    'precio': np.random.randint(2400,10000,n_ventas),
    'cantidad':np.random.randint(1,7,n_ventas)
})

df_ventas.head()
# Out:
#    id  rubro  precio  cantidad
# 0   0      0    3645         1
# 1   1      2    6821         1
# 2   2      1    8554         2
# 3   3      2    5403         5
# 4   4      1    5358         5

# %%
df_merged = df_ventas.merge(df,left_on='rubro', right_on='id', validate='many_to_one')
df_merged
# Out:
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0      0      0    3645         1     0  vestuario
# 1      1      2    6821         1     2      hogar
# 2      2      1    8554         2     1    calzado
# 3      3      2    5403         5     2      hogar
# 4      4      1    5358         5     1    calzado
# ..   ...    ...     ...       ...   ...        ...
# 95    95      0    4494         2     0  vestuario
# 96    96      1    8348         3     1    calzado
# 97    97      1    2478         2     1    calzado
# 98    98      2    9863         4     2      hogar
# 99    99      1    7615         5     1    calzado
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Duplicados

# %%
df = df_merged
df
# Out:
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0      0      0    3645         1     0  vestuario
# 1      1      2    6821         1     2      hogar
# 2      2      1    8554         2     1    calzado
# 3      3      2    5403         5     2      hogar
# 4      4      1    5358         5     1    calzado
# ..   ...    ...     ...       ...   ...        ...
# 95    95      0    4494         2     0  vestuario
# 96    96      1    8348         3     1    calzado
# 97    97      1    2478         2     1    calzado
# 98    98      2    9863         4     2      hogar
# 99    99      1    7615         5     1    calzado
#
# [100 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0      0      0    3645         1     0  vestuario
# 1      1      2    6821         1     2      hogar
# 2      2      1    8554         2     1    calzado
# 3      3      2    5403         5     2      hogar
# 4      4      1    5358         5     1    calzado
# ..   ...    ...     ...       ...   ...        ...
# 95    95      0    4494         2     0  vestuario
# 96    96      1    8348         3     1    calzado
# 97    97      1    2478         2     1    calzado
# 98    98      2    9863         4     2      hogar
# 99    99      1    7615         5     1    calzado
#
# [100 rows x 6 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_x, rubro, precio, cantidad, id_y, des_rubro]
# Index: []

# %%
df.duplicated(subset=['rubro'])
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Length: 100, dtype: bool

# %% [markdown]
# ### Datos faltantes

# %%
np.nan, type(np.nan)
# Out:
# (nan, float)

# %%
df[df['rubro'].isna()]
# Out:
# Empty DataFrame
# Columns: [id_x, rubro, precio, cantidad, id_y, des_rubro]
# Index: []

# %%
df.isna().sum()
# Out:
# id_x         0
# rubro        0
# precio       0
# cantidad     0
# id_y         0
# des_rubro    0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0      0      0    3645         1     0  vestuario
# 1      1      2    6821         1     2      hogar
# 2      2      1    8554         2     1    calzado
# 3      3      2    5403         5     2      hogar
# 4      4      1    5358         5     1    calzado
# ..   ...    ...     ...       ...   ...        ...
# 95    95      0    4494         2     0  vestuario
# 96    96      1    8348         3     1    calzado
# 97    97      1    2478         2     1    calzado
# 98    98      2    9863         4     2      hogar
# 99    99      1    7615         5     1    calzado
#
# [100 rows x 6 columns]

# %%
df.fillna(0)
# Out:
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0      0      0    3645         1     0  vestuario
# 1      1      2    6821         1     2      hogar
# 2      2      1    8554         2     1    calzado
# 3      3      2    5403         5     2      hogar
# 4      4      1    5358         5     1    calzado
# ..   ...    ...     ...       ...   ...        ...
# 95    95      0    4494         2     0  vestuario
# 96    96      1    8348         3     1    calzado
# 97    97      1    2478         2     1    calzado
# 98    98      2    9863         4     2      hogar
# 99    99      1    7615         5     1    calzado
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Metodo APPLY

# %%
df['rubro'].apply(lambda x: x+1) #Para cada uno de los valores de 'rubro' le suma 1
# Out:
# 0     1
# 1     3
# 2     2
# 3     3
# 4     2
#      ..
# 95    1
# 96    2
# 97    2
# 98    3
# 99    2
# Name: rubro, Length: 100, dtype: int64

# %%
df['id_x'].apply(lambda x: x +1 if x>8 else x)
df
# Out:
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0      0      0    3645         1     0  vestuario
# 1      1      2    6821         1     2      hogar
# 2      2      1    8554         2     1    calzado
# 3      3      2    5403         5     2      hogar
# 4      4      1    5358         5     1    calzado
# ..   ...    ...     ...       ...   ...        ...
# 95    95      0    4494         2     0  vestuario
# 96    96      1    8348         3     1    calzado
# 97    97      1    2478         2     1    calzado
# 98    98      2    9863         4     2      hogar
# 99    99      1    7615         5     1    calzado
#
# [100 rows x 6 columns]

# %%
df.applymap(lambda x: x.upper() if type(x) == str else x/2)
# Out:
# C:\Users\Federico\AppData\Local\Temp\ipykernel_11744\3712740357.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x.upper() if type(x) == str else x/2)
#     id_x  rubro  precio  cantidad  id_y  des_rubro
# 0    0.0    0.0  1822.5       0.5   0.0  VESTUARIO
# 1    0.5    1.0  3410.5       0.5   1.0      HOGAR
# 2    1.0    0.5  4277.0       1.0   0.5    CALZADO
# 3    1.5    1.0  2701.5       2.5   1.0      HOGAR
# 4    2.0    0.5  2679.0       2.5   0.5    CALZADO
# ..   ...    ...     ...       ...   ...        ...
# 95  47.5    0.0  2247.0       1.0   0.0  VESTUARIO
# 96  48.0    0.5  4174.0       1.5   0.5    CALZADO
# 97  48.5    0.5  1239.0       1.0   0.5    CALZADO
# 98  49.0    1.0  4931.5       2.0   1.0      HOGAR
# 99  49.5    0.5  3807.5       2.5   0.5    CALZADO
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Reemplazar datos

# %%
df = pd.read_excel('DataFrame.xlsx')
df
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima    Acusado Día de semana
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves
# 1      20       8       PEATON-AUTO  PEATON       AUTO       Viernes
# 2      11       7       MOTO-CARGAS    MOTO     CARGAS        Martes
# 3      15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles
# 4      14      15         MOTO-OTRO    MOTO       OTRO         Lunes
# ..    ...     ...               ...     ...        ...           ...
# 712    16       3       PEATON-MOTO  PEATON       MOTO        Martes
# 713    12      12     PEATON-CARGAS  PEATON     CARGAS        Jueves
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes
# 715    15       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles
# 716    10       9     PEATON-CARGAS  PEATON     CARGAS        Jueves
#
# [717 rows x 12 columns]

# %%
# Reemplazar un elemento específico

df.replace('PASAJEROS','PASAJERO')

# Haciendolo de esta forma no quedá guardado en df, tendría que definir df o agregar , inplace=True
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima   Acusado Día de semana
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJERO        Jueves
# 1      20       8       PEATON-AUTO  PEATON      AUTO       Viernes
# 2      11       7       MOTO-CARGAS    MOTO    CARGAS        Martes
# 3      15       1       MOTO-CARGAS    MOTO    CARGAS     Miercoles
# 4      14      15         MOTO-OTRO    MOTO      OTRO         Lunes
# ..    ...     ...               ...     ...       ...           ...
# 712    16       3       PEATON-MOTO  PEATON      MOTO        Martes
# 713    12      12     PEATON-CARGAS  PEATON    CARGAS        Jueves
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJERO        Martes
# 715    15       4     PEATON-CARGAS  PEATON    CARGAS     Miercoles
# 716    10       9     PEATON-CARGAS  PEATON    CARGAS        Jueves
#
# [717 rows x 12 columns]

# %%
df.replace({'Día de semana': r'Martes'}, {'Día de semana': 'Mondongo'}, regex=True)
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima    Acusado Día de semana
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves
# 1      20       8       PEATON-AUTO  PEATON       AUTO       Viernes
# 2      11       7       MOTO-CARGAS    MOTO     CARGAS      Mondongo
# 3      15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles
# 4      14      15         MOTO-OTRO    MOTO       OTRO         Lunes
# ..    ...     ...               ...     ...        ...           ...
# 712    16       3       PEATON-MOTO  PEATON       MOTO      Mondongo
# 713    12      12     PEATON-CARGAS  PEATON     CARGAS        Jueves
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJEROS      Mondongo
# 715    15       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles
# 716    10       9     PEATON-CARGAS  PEATON     CARGAS        Jueves
#
# [717 rows x 12 columns]

# %% [markdown]
# ___
#
# ### Discretización de datos

# %% [markdown]
# Metodo pd.cut()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     717 non-null    int64
#  1   ID             717 non-null    object
#  2   Rol            717 non-null    object
#  3   Sexo           717 non-null    object
#  4   Edad           717 non-null    int64
#  5   Fecha          717 non-null    object
#  6   Hora           717 non-null    int64
#  7   Comuna         717 non-null    int64
#  8   Participantes  717 non-null    object
#  9   Victima        708 non-null    object
#  10  Acusado        694 non-null    object
#  11  Día de semana  717 non-null    object
#  12  GrupoEdad      634 non-null    category
# dtypes: category(1), int64(4), object(8)
# memory usage: 68.4+ KB

# %%
# Discretizar las edades en intervalos

intervalos = [-1,20,40,60,100]
# Definir etiquetas
etiquetas= ['Niño','Adolecente','Adulto','Veterano-anciano']

# Discretizar y devolver valores en lugar de intervalos
df['GrupoEdad'] = pd.cut(df['Edad'], bins=intervalos, labels=etiquetas)

df
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima    Acusado Día de semana  \
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves
# 1      20       8       PEATON-AUTO  PEATON       AUTO       Viernes
# 2      11       7       MOTO-CARGAS    MOTO     CARGAS        Martes
# 3      15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles
# 4      14      15         MOTO-OTRO    MOTO       OTRO         Lunes
# ..    ...     ...               ...     ...        ...           ...
# 712    16       3       PEATON-MOTO  PEATON       MOTO        Martes
# 713    12      12     PEATON-CARGAS  PEATON     CARGAS        Jueves
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes
# 715    15       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles
# 716    10       9     PEATON-CARGAS  PEATON     CARGAS        Jueves
#
#             GrupoEdad
# 0                Niño
# 1                Niño
# 2                Niño
# 3                Niño
# 4                Niño
# ..                ...
# 712  Veterano-anciano
# 713  Veterano-anciano
# 714  Veterano-anciano
# 715  Veterano-anciano
# 716  Veterano-anciano
#
# [717 rows x 13 columns]

# %%
# Discretizar las edades en intervalos

intervalos = [-1,20,40,60,100]
# Definir etiquetas
etiquetas= [1,2,3,4]

# Discretizar y devolver valores en lugar de intervalos
df['GrupoEdad'] = pd.cut(df['Edad'], bins=intervalos, labels=etiquetas)

df['GrupoEdad'] = pd.to_numeric(df['GrupoEdad'])

df
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima    Acusado Día de semana  \
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves
# 1      20       8       PEATON-AUTO  PEATON       AUTO       Viernes
# 2      11       7       MOTO-CARGAS    MOTO     CARGAS        Martes
# 3      15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles
# 4      14      15         MOTO-OTRO    MOTO       OTRO         Lunes
# ..    ...     ...               ...     ...        ...           ...
# 712    16       3       PEATON-MOTO  PEATON       MOTO        Martes
# 713    12      12     PEATON-CARGAS  PEATON     CARGAS        Jueves
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes
# 715    15       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles
# 716    10       9     PEATON-CARGAS  PEATON     CARGAS        Jueves
#
#      GrupoEdad
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 712          4
# 713          4
# 714          4
# 715          4
# 716          4
#
# [717 rows x 13 columns]

# %% [markdown]
# Una alternativa al metodo utilizado pd.to_numeric() es  **.astype()**

# %%
# Discretizar las edades en intervalos

intervalos = [-1,20,40,60,100]
# Definir etiquetas
etiquetas= [1,2,3,4]

# Discretizar y devolver valores en lugar de intervalos
df['GrupoEdad'] = pd.cut(df['Edad'], bins=intervalos, labels=etiquetas)

df.astype({'GrupoEdad':'Int64'}).dtypes

df
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima    Acusado Día de semana GrupoEdad
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves         1
# 1      20       8       PEATON-AUTO  PEATON       AUTO       Viernes         1
# 2      11       7       MOTO-CARGAS    MOTO     CARGAS        Martes         1
# 3      15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles         1
# 4      14      15         MOTO-OTRO    MOTO       OTRO         Lunes         1
# ..    ...     ...               ...     ...        ...           ...       ...
# 712    16       3       PEATON-MOTO  PEATON       MOTO        Martes         4
# 713    12      12     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes         4
# 715    15       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles         4
# 716    10       9     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
#
# [717 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     717 non-null    int64
#  1   ID             717 non-null    object
#  2   Rol            717 non-null    object
#  3   Sexo           717 non-null    object
#  4   Edad           717 non-null    int64
#  5   Fecha          717 non-null    object
#  6   Hora           717 non-null    int64
#  7   Comuna         717 non-null    int64
#  8   Participantes  717 non-null    object
#  9   Victima        708 non-null    object
#  10  Acusado        694 non-null    object
#  11  Día de semana  717 non-null    object
#  12  GrupoEdad      717 non-null    category
# dtypes: category(1), int64(4), object(8)
# memory usage: 68.2+ KB

# %% [markdown]
# ### METODO WHERE()

# %%
df.head()
# Out:
#    Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0         461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1         631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2          30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3         530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4         529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
#
#    Hora  Comuna     Participantes Victima    Acusado Día de semana GrupoEdad
# 0     7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves         1
# 1    20       8       PEATON-AUTO  PEATON       AUTO       Viernes         1
# 2    11       7       MOTO-CARGAS    MOTO     CARGAS        Martes         1
# 3    15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles         1
# 4    14      15         MOTO-OTRO    MOTO       OTRO         Lunes         1

# %%
umbral = df['Hora'].mean()
umbral
# Out:
# 11.553695955369596

# %%
# Utilizando np.where() para clasificar horario

df['Momento'] = np.where(df['Hora'] >= umbral, 'Tarde','Temprano')

df
# Out:
#      Unnamed: 0         ID                   Rol       Sexo  Edad       Fecha  \
# 0           461  2019-0026                PEATON  MASCULINO     0  2019-03-28
# 1           631  2021-0012                PEATON  MASCULINO     0  2021-01-29
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE  MASCULINO     0  2016-03-29
# 3           530  2019-0095             CONDUCTOR  MASCULINO     0  2019-11-20
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE   FEMENINO     0  2019-11-18
# ..          ...        ...                   ...        ...   ...         ...
# 712         690  2021-0071                PEATON  MASCULINO    88  2021-08-31
# 713         594  2020-0055                PEATON  MASCULINO    91  2020-11-19
# 714         566  2020-0028                PEATON  MASCULINO    91  2020-05-19
# 715         524  2019-0089                PEATON   FEMENINO    92  2019-10-23
# 716         213  2017-0080                PEATON   FEMENINO    95  2017-06-22
#
#      Hora  Comuna     Participantes Victima    Acusado Día de semana  \
# 0       7       8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves
# 1      20       8       PEATON-AUTO  PEATON       AUTO       Viernes
# 2      11       7       MOTO-CARGAS    MOTO     CARGAS        Martes
# 3      15       1       MOTO-CARGAS    MOTO     CARGAS     Miercoles
# 4      14      15         MOTO-OTRO    MOTO       OTRO         Lunes
# ..    ...     ...               ...     ...        ...           ...
# 712    16       3       PEATON-MOTO  PEATON       MOTO        Martes
# 713    12      12     PEATON-CARGAS  PEATON     CARGAS        Jueves
# 714    10      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes
# 715    15       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles
# 716    10       9     PEATON-CARGAS  PEATON     CARGAS        Jueves
#
#     GrupoEdad   Momento
# 0           1  Temprano
# 1           1     Tarde
# 2           1  Temprano
# 3           1     Tarde
# 4           1     Tarde
# ..        ...       ...
# 712         4     Tarde
# 713         4     Tarde
# 714         4  Temprano
# 715         4     Tarde
# 716         4  Temprano
#
# [717 rows x 14 columns]

# %% [markdown]
# ### Get dummies

# %%
# Utilizando GetDummies, las variables binarias pasan a tener un valor asignado

#Ejemplo con la columna de genero: FEMENINO  /  MASCULINO

pd.get_dummies(df,columns=['Sexo'])
# Out:
#      Unnamed: 0         ID                   Rol  Edad       Fecha  Hora  \
# 0           461  2019-0026                PEATON     0  2019-03-28     7
# 1           631  2021-0012                PEATON     0  2021-01-29    20
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE     0  2016-03-29    11
# 3           530  2019-0095             CONDUCTOR     0  2019-11-20    15
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE     0  2019-11-18    14
# ..          ...        ...                   ...   ...         ...   ...
# 712         690  2021-0071                PEATON    88  2021-08-31    16
# 713         594  2020-0055                PEATON    91  2020-11-19    12
# 714         566  2020-0028                PEATON    91  2020-05-19    10
# 715         524  2019-0089                PEATON    92  2019-10-23    15
# 716         213  2017-0080                PEATON    95  2017-06-22    10
#
#      Comuna     Participantes Victima    Acusado Día de semana GrupoEdad  \
# 0         8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves         1
# 1         8       PEATON-AUTO  PEATON       AUTO       Viernes         1
# 2         7       MOTO-CARGAS    MOTO     CARGAS        Martes         1
# 3         1       MOTO-CARGAS    MOTO     CARGAS     Miercoles         1
# 4        15         MOTO-OTRO    MOTO       OTRO         Lunes         1
# ..      ...               ...     ...        ...           ...       ...
# 712       3       PEATON-MOTO  PEATON       MOTO        Martes         4
# 713      12     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
# 714      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes         4
# 715       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles         4
# 716       9     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
#
#       Momento  Sexo_FEMENINO  Sexo_MASCULINO  Sexo_SD
# 0    Temprano          False            True    False
# 1       Tarde          False            True    False
# 2    Temprano          False            True    False
# 3       Tarde          False            True    False
# 4       Tarde           True           False    False
# ..        ...            ...             ...      ...
# 712     Tarde          False            True    False
# 713     Tarde          False            True    False
# 714  Temprano          False            True    False
# 715     Tarde           True           False    False
# 716  Temprano           True           False    False
#
# [717 rows x 16 columns]

# %%
# Utilizando GetDummies, las variables binarias pasan a tener un valor asignado

#Ejemplo con la columna de genero: FEMENINO  /  MASCULINO

# Sin generar la primer columna

df = pd.get_dummies(df,columns=['Sexo'], drop_first=True)

df.rename(columns={'Sexo_MASCULINO': 'Sexo_Binario'}, inplace=True)

df['Sexo_Binario'] = df['Sexo_Binario'].astype(int)

# %%
df
# Out:
#      Unnamed: 0         ID                   Rol  Edad       Fecha  Hora  \
# 0           461  2019-0026                PEATON     0  2019-03-28     7
# 1           631  2021-0012                PEATON     0  2021-01-29    20
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE     0  2016-03-29    11
# 3           530  2019-0095             CONDUCTOR     0  2019-11-20    15
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE     0  2019-11-18    14
# ..          ...        ...                   ...   ...         ...   ...
# 712         690  2021-0071                PEATON    88  2021-08-31    16
# 713         594  2020-0055                PEATON    91  2020-11-19    12
# 714         566  2020-0028                PEATON    91  2020-05-19    10
# 715         524  2019-0089                PEATON    92  2019-10-23    15
# 716         213  2017-0080                PEATON    95  2017-06-22    10
#
#      Comuna     Participantes Victima    Acusado Día de semana GrupoEdad  \
# 0         8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves         1
# 1         8       PEATON-AUTO  PEATON       AUTO       Viernes         1
# 2         7       MOTO-CARGAS    MOTO     CARGAS        Martes         1
# 3         1       MOTO-CARGAS    MOTO     CARGAS     Miercoles         1
# 4        15         MOTO-OTRO    MOTO       OTRO         Lunes         1
# ..      ...               ...     ...        ...           ...       ...
# 712       3       PEATON-MOTO  PEATON       MOTO        Martes         4
# 713      12     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
# 714      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes         4
# 715       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles         4
# 716       9     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
#
#       Momento  Sexo_Binario
# 0    Temprano             1
# 1       Tarde             1
# 2    Temprano             1
# 3       Tarde             1
# 4       Tarde             0
# ..        ...           ...
# 712     Tarde             1
# 713     Tarde             1
# 714  Temprano             1
# 715     Tarde             0
# 716  Temprano             0
#
# [717 rows x 14 columns]

# %%
df = df.drop(columns='Sexo_SD')

# %% [markdown]
# ### Manipulacion de STRINGS

# %%
df
# Out:
#      Unnamed: 0         ID                   Rol  Edad       Fecha  Hora  \
# 0           461  2019-0026                PEATON     0  2019-03-28     7
# 1           631  2021-0012                PEATON     0  2021-01-29    20
# 2            30  2016-0041  PASAJERO_ACOMPAÑANTE     0  2016-03-29    11
# 3           530  2019-0095             CONDUCTOR     0  2019-11-20    15
# 4           529  2019-0094  PASAJERO_ACOMPAÑANTE     0  2019-11-18    14
# ..          ...        ...                   ...   ...         ...   ...
# 712         690  2021-0071                PEATON    88  2021-08-31    16
# 713         594  2020-0055                PEATON    91  2020-11-19    12
# 714         566  2020-0028                PEATON    91  2020-05-19    10
# 715         524  2019-0089                PEATON    92  2019-10-23    15
# 716         213  2017-0080                PEATON    95  2017-06-22    10
#
#      Comuna     Participantes Victima    Acusado Día de semana GrupoEdad  \
# 0         8  PEATON-PASAJEROS  PEATON  PASAJEROS        Jueves         1
# 1         8       PEATON-AUTO  PEATON       AUTO       Viernes         1
# 2         7       MOTO-CARGAS    MOTO     CARGAS        Martes         1
# 3         1       MOTO-CARGAS    MOTO     CARGAS     Miercoles         1
# 4        15         MOTO-OTRO    MOTO       OTRO         Lunes         1
# ..      ...               ...     ...        ...           ...       ...
# 712       3       PEATON-MOTO  PEATON       MOTO        Martes         4
# 713      12     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
# 714      15  PEATON-PASAJEROS  PEATON  PASAJEROS        Martes         4
# 715       4     PEATON-CARGAS  PEATON     CARGAS     Miercoles         4
# 716       9     PEATON-CARGAS  PEATON     CARGAS        Jueves         4
#
#       Momento  Sexo_Binario
# 0    Temprano             1
# 1       Tarde             1
# 2    Temprano             1
# 3       Tarde             1
# 4       Tarde             0
# ..        ...           ...
# 712     Tarde             1
# 713     Tarde             1
# 714  Temprano             1
# 715     Tarde             0
# 716  Temprano             0
#
# [717 rows x 14 columns]

# %%
df['Rol'].str.lower()
# Out:
# 0                    peaton
# 1                    peaton
# 2      pasajero_acompañante
# 3                 conductor
# 4      pasajero_acompañante
#                ...
# 712                  peaton
# 713                  peaton
# 714                  peaton
# 715                  peaton
# 716                  peaton
# Name: Rol, Length: 717, dtype: object

# %% [markdown]
# str.
# - upper()
# - lower()
# - isupper()
# - islower()
# - isnumeric()
# - replace()
# - split()
# - contains()
# - find()

# %% [markdown]
# ### Manipulación de DATE y TIME

# %%
df_fechas = df[['ID','Fecha','Día de semana']]

# %%
df_fechas
# Out:
#             ID       Fecha Día de semana
# 0    2019-0026  2019-03-28        Jueves
# 1    2021-0012  2021-01-29       Viernes
# 2    2016-0041  2016-03-29        Martes
# 3    2019-0095  2019-11-20     Miercoles
# 4    2019-0094  2019-11-18         Lunes
# ..         ...         ...           ...
# 712  2021-0071  2021-08-31        Martes
# 713  2020-0055  2020-11-19        Jueves
# 714  2020-0028  2020-05-19        Martes
# 715  2019-0089  2019-10-23     Miercoles
# 716  2017-0080  2017-06-22        Jueves
#
# [717 rows x 3 columns]

# %%
df_fechas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             717 non-null    object
#  1   Fecha          717 non-null    object
#  2   Día de semana  717 non-null    object
# dtypes: object(3)
# memory usage: 16.9+ KB

# %%
df_fechas['Fecha'] = pd.to_datetime(df['Fecha'])
df_fechas
# Out:
# C:\Users\Federico\AppData\Local\Temp\ipykernel_11744\1727325063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fechas['Fecha'] = pd.to_datetime(df['Fecha'])
#             ID      Fecha Día de semana
# 0    2019-0026 2019-03-28        Jueves
# 1    2021-0012 2021-01-29       Viernes
# 2    2016-0041 2016-03-29        Martes
# 3    2019-0095 2019-11-20     Miercoles
# 4    2019-0094 2019-11-18         Lunes
# ..         ...        ...           ...
# 712  2021-0071 2021-08-31        Martes
# 713  2020-0055 2020-11-19        Jueves
# 714  2020-0028 2020-05-19        Martes
# 715  2019-0089 2019-10-23     Miercoles
# 716  2017-0080 2017-06-22        Jueves
#
# [717 rows x 3 columns]

# %%
df_fechas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             717 non-null    object
#  1   Fecha          717 non-null    datetime64[ns]
#  2   Día de semana  717 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 16.9+ KB

# %%
# Para acceder a los métodos de fecha usando .dt



df_fechas[df_fechas['Fecha'].dt.year == 2020]
# Out:
#             ID      Fecha Día de semana
# 31   2020-0040 2020-09-12        Sabado
# 34   2020-0034 2020-08-02       Domingo
# 37   2020-0025 2020-05-12        Martes
# 38   2020-0017 2020-03-05        Jueves
# 42   2020-0014 2020-02-27        Jueves
# ..         ...        ...           ...
# 700  2020-0057 2020-11-23         Lunes
# 707  2020-0001 2020-01-04        Sabado
# 711  2020-0021 2020-03-14        Sabado
# 713  2020-0055 2020-11-19        Jueves
# 714  2020-0028 2020-05-19        Martes
#
# [81 rows x 3 columns]

# %%
df_fechas['Fecha'].dt.day
# Out:
# 0      28
# 1      29
# 2      29
# 3      20
# 4      18
#        ..
# 712    31
# 713    19
# 714    19
# 715    23
# 716    22
# Name: Fecha, Length: 717, dtype: int32

# %%
df_fechas['Dia'] = df_fechas['Fecha'].dt.day
df_fechas['Mes'] = df_fechas['Fecha'].dt.month
df_fechas['Año'] = df_fechas['Fecha'].dt.year
# Out:
# C:\Users\Federico\AppData\Local\Temp\ipykernel_11744\1963179018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fechas['Dia'] = df_fechas['Fecha'].dt.day
# C:\Users\Federico\AppData\Local\Temp\ipykernel_11744\1963179018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fechas['Mes'] = df_fechas['Fecha'].dt.month
# C:\Users\Federico\AppData\Local\Temp\ipykernel_11744\1963179018.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fechas['Año'] = df_fechas['Fecha'].dt.year

# %%
df_fechas
# Out:
#             ID      Fecha Día de semana  Dia  Mes   Año
# 0    2019-0026 2019-03-28        Jueves   28    3  2019
# 1    2021-0012 2021-01-29       Viernes   29    1  2021
# 2    2016-0041 2016-03-29        Martes   29    3  2016
# 3    2019-0095 2019-11-20     Miercoles   20   11  2019
# 4    2019-0094 2019-11-18         Lunes   18   11  2019
# ..         ...        ...           ...  ...  ...   ...
# 712  2021-0071 2021-08-31        Martes   31    8  2021
# 713  2020-0055 2020-11-19        Jueves   19   11  2020
# 714  2020-0028 2020-05-19        Martes   19    5  2020
# 715  2019-0089 2019-10-23     Miercoles   23   10  2019
# 716  2017-0080 2017-06-22        Jueves   22    6  2017
#
# [717 rows x 6 columns]

# %%
df_fechas.loc[:, 'Dia'] = df_fechas['Fecha'].dt.day
df_fechas.loc[:, 'Mes'] = df_fechas['Fecha'].dt.month
df_fechas.loc[:, 'Año'] = df_fechas['Fecha'].dt.year

# %%
df_fechas = df_fechas.copy

# %%
df_fechas
# Out:
# <bound method NDFrame.copy of             ID      Fecha Día de semana  Dia  Mes   Año
# 0    2019-0026 2019-03-28        Jueves   28    3  2019
# 1    2021-0012 2021-01-29       Viernes   29    1  2021
# 2    2016-0041 2016-03-29        Martes   29    3  2016
# 3    2019-0095 2019-11-20     Miercoles   20   11  2019
# 4    2019-0094 2019-11-18         Lunes   18   11  2019
# ..         ...        ...           ...  ...  ...   ...
# 712  2021-0071 2021-08-31        Martes   31    8  2021
# 713  2020-0055 2020-11-19        Jueves   19   11  2020
# 714  2020-0028 2020-05-19        Martes   19    5  2020
# 715  2019-0089 2019-10-23     Miercoles   23   10  2019
# 716  2017-0080 2017-06-22        Jueves   22    6  2017
#
# [717 rows x 6 columns]>

# %%
# Convertir a formato de fecha y hora de Pandas. Especificamos el formato de entrada

df_fechas = pd.DataFrame({
    'Fecha': ['02-05-2021','03-04-2032','23-08-1995']
})
df_fechas['Fecha'] = pd.to_datetime(df_fechas['Fecha'], format= '%d-%m-%Y')
# df_fechas['Fecha'] = pd.to_datetime(df['Fecha'], format='%Y-%m-%d')
df_fechas
# Out:
#        Fecha
# 0 2021-05-02
# 1 2032-04-03
# 2 1995-08-23

# %%
df_fechas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 156.0 bytes

# %%
df_2021 = df_fechas[df_fechas['Fecha'].dt.year == 2021]   # no tengo que comparar con un STR

# %%
df_2021
# Out:
#        Fecha
# 0 2021-05-02
